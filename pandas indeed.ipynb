# %%
import pandas

frame = pandas.read_csv('data/resumes.csv', delimiter=',', quotechar="'")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-2-0f4247bcf23d> in <module>()
#       1 import pandas
#       2
# ----> 3 frame = pandas.read_csv('data/resumes.csv', delimiter=',', quotechar="'")
#
# ...

# %%
frame.groupby(['person'])
